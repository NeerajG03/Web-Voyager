# %%
from script import main_call
await main_call("How long by car from bangalore to goa check in google maps")
# Out:
# 1. Type: ['7', '"Bangalore to Goa driving time"']
# 2. ANSWER;: ['The driving time from Bangalore to Goa is approximately 10 hours and 30 minutes via NH 48, covering a distance of 556.1 km.']
#
#
# -------
# Final response:
# The driving time from Bangalore to Goa is approximately 10 hours and 30 minutes via NH 48, covering a distance of 556.1 km.

# %%
await main_call("Latest model launch from OpenAI")
# Out:
# 1. Type: ['7', '"Latest model launch from OpenAI"']
# 2. Click: ['14']
# 3. ANSWER;: ['The latest model launch from OpenAI is called "Strawberry," which is designed for the ChatGPT service and is expected to launch within two weeks.']
#
#
# -------
# Final response:
# The latest model launch from OpenAI is called "Strawberry," which is designed for the ChatGPT service and is expected to launch within two weeks.

# %%
await main_call("What is the current stock price of NVIDIA")
# Out:
# 1. Type: ['7', '"NVIDIA stock price"']
# 2. ANSWER;: ['The current stock price of NVIDIA is $116.00 USD.']
#
#
# -------
# Final response:
# The current stock price of NVIDIA is $116.00 USD.

# %%
await main_call("What is the upcoming marvel movie all about? today is sep 22 2024")
# Out:
# 1. Click: ['7']
# 2. Type: ['7', 'upcoming Marvel movie September 2024']
# 3. ANSWER;: ['There is no Marvel movie specifically releasing in September 2024. The next Marvel movie mentioned is "Blade," set to release on November 7, 2025.']
#
#
# -------
# Final response:
# There is no Marvel movie specifically releasing in September 2024. The next Marvel movie mentioned is "Blade," set to release on November 7, 2025.
