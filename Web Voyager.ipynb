# %%
from script import main_call
# await main_call("How long by car from bangalore to goa check in google maps")
# Out:
# /Users/neerajgopalakrishnan/Documents/Github/Web-Voyager/venv-web-voyager/lib/python3.12/site-packages/langsmith/client.py:323: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(

# %%
await main_call("Latest model launch from OpenAI")
# Out:
# 1. Type: ['7', '"Latest model launch from OpenAI"']
# 2. Click: ['14']
# 3. ANSWER;: ['The latest model launch from OpenAI is called "Strawberry," which is designed for the ChatGPT service and is expected to launch within two weeks.']
#
#
# -------
# Final response:
# The latest model launch from OpenAI is called "Strawberry," which is designed for the ChatGPT service and is expected to launch within two weeks.

# %%
await main_call("What is the current stock price of NVIDIA")
# Out:
# 1. Type: ['7', '"NVIDIA stock price"']
# 2. ANSWER;: ['The current stock price of NVIDIA is $116.00 USD.']
#
#
# -------
# Final response:
# The current stock price of NVIDIA is $116.00 USD.

# %%
await main_call("WHo are the customers of coyotesoftware? get data from https://coyotesoftware.co.uk/client-stories/")
# Out:
# 1. Type: ['7', 'coyotesoftware client stories']
# 2. Click: ['20']
# 3. Click: ['5']
# 4. retry: Could not parse LLM Output: I'm unable to browse the web in real-time. However, you can click on the "Client Stories" section of the Coyote Software website to learn more about their customers. If you have any specific questions or need further assistance, feel free to ask!
# 5. retry: Could not parse LLM Output: I'm unable to browse the web in real-time or access external websites. However, you can visit the Coyote Software website and navigate to the "Client Stories" section to find information about their customers.
# 6. retry: Could not parse LLM Output: I'm unable to browse the web in real-time, but based on the screenshot, Coyote Software partners with more than 60 leading real estate businesses globally. For specific client stories, you can explore their "Client Stories" section on their website.
#
# Would you like me to assist with anything else?
# 7. Scroll: ['WINDOW', 'down']
# 8. Click: ['5']
# 9. Click: ['5']
# 10. Click: ['5']
# 11. Click: ['5']
# 12. Scroll: ['WINDOW', 'down']
# 13. Click: ['5']
# 14. Click: ['5']
# 15. ANSWER;: ['Coyote partners with more than 60 leading real estate businesses globally, including Nuveen, Oxford, LGIM, Mirastar, Global Mutual, and Caisson.']
#
#
# -------
# Final response:
# Coyote partners with more than 60 leading real estate businesses globally, including Nuveen, Oxford, LGIM, Mirastar, Global Mutual, and Caisson.
